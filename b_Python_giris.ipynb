# %% [markdown]
# **Python Giriş**
#
# ![image.png](data:image/png;base64,...)

# %%
print("Merhaba Dünya")
# Out:
# Merhaba Dünya

# %%
3+5 # notebook'a ozgu bu sekilde calistirilir
# Out:
# 8

# %%
print(3+5)
# Out:
# 8

# %% [markdown]
# Google Colab'i tarayıcı açabildiğimiz herhangi bir mobil cihazdan da kullanabiliyoruz.

# %% [markdown]
# **Web Sitem:**  [Bora KOL Portfolyo](https://borakol.github.io/portfolio-en/)

# %%
print("E"+"C"+"S")
# Out:
# ECS

# %%
print("3"+"6"+"9")
# Out:
# 369

# %%
degisken=369
type(degisken)
# Out:
# int

# %%
degisken2="3"+"6"+"9"
type(degisken2)
# Out:
# str

# %%
print(3*3)
# Out:
# 9

# %%
print("3"*3)
# Out:
# 333

# %%
print(3*"A")
# Out:
# AAA

# %%
print("Bora","Kol")
# Out:
# Bora Kol

# %%
ad="Bora"
soyad="Kol"
yas=24
print(ad,soyad,yas)
# Out:
# Bora Kol 24

# %% [markdown]
# # Başlık
# ## Alt Başlık
#
# > alıntı bloku
# >> alıntı bloku

# %%
print("""
1.Girdi
2.İşlem
3.Sonuç
""")
# Out:
# 1.Girdi
# 2.İşlem
# 3.Sonuç

# %%
print("\nmerhaba")
# Out:
# merhaba

# %%
print("merhaba\t\tarkadaşlar\tnasılsınız?")
# Out:
# merhaba		arkadaşlar	nasılsınız?

# %%
sayi=1
sayi="bora"

# %%
sayi
# Out:
# 'bora'

# %%
sayi1=sayi
sayi=5
print(sayi1)
# Out:
# bora

# %%
print(sayi)
# Out:
# 5

# %%
tamsayi=5
type(tamsayi)
# Out:
# int

# %%
ondalikli_sayi=5.0
type(ondalikli_sayi)
# Out:
# float

# %%
isim="bora"
type(isim)
# Out:
# str

# %%
isim_listesi=["Bora","Kol",24]
type(isim_listesi)
# Out:
# list

# %%
isim_listesi[0]
# Out:
# 'Bora'

# %%
type(isim_listesi[0]) # Bora
# Out:
# str

# %%
type(isim_listesi[2]) # 24
# Out:
# int

# %% [markdown]
# Pythonda liste içinde karışık türden ögeler bulunabilir.

# %%
# değişkenler
# Baharat kutusu
tuzluk = "tuz"
print("Tuzluk içinde ne var : " , tuzluk) # değişken tuzluk , içindeki değer ise tuz
# Out:
# Tuzluk içinde ne var :  tuz

# %%
tuzluk="karabiber"
print("Tuzluk içinde ne var: " , tuzluk) # böyle değişken adlandırması olmaz, mantıklı atamalar yapılması gerekir.
# Out:
# Tuzluk içinde ne var:  karabiber

# %% [markdown]
# # Değişkenlerle İlgili Özellikler
#
# 1.   Değişken adı sayı ile başlayamaz
# 2.   Python tarafından kullanılan özel sözcükler olamaz
# 3.   Değişken adı değerle uyumlu olmalı(yukarıdaki tuzluk="karabiber" örneği gibi)
# 4.   Kısa ve anlamlı değişken adları kullanılmalı. Tercihen İngilizce isimler seçilmeli.
#
#
# 1.   Snake Case kullanılır(örn: kimlik_no)

# %% [markdown]
# <table>
#   <tr>
#     <th>ad</th>
#     <th>soyad</th>
#   </tr>
#   <tr>
#     <td>Bora</td>
#     <td>KOL</td>
#   </tr>
# </table>

# %%
liste = [["Sena" , "Şamlıoğlu" , 22] ,
         ["Rana" , "Selim" , 26],
         ["Kübra" , "Kılıç" , 24] ,
         ["Hakan" , "Kiran" , 37] ,
         ["Murat" ,"Altun", 44]
]

# %%
liste[0]
# Out:
# ['Sena', 'Şamlıoğlu', 22]

# %%
type(liste[0])
# Out:
# list

# %%
## sena'nın yaş bilgisini alalım
liste[0][2]
# Out:
# 22

# %%
type(liste[0][2])
# Out:
# int

# %% [markdown]
# **String metotları**

# %%
metin="Python programlama dili"
print(metin.upper())
print(metin)
# Out:
# PYTHON PROGRAMLAMA DILI
# Python programlama dili

# %%
# insan
# insanın bazı özellikleri vardır
# fiziksel özellikler , kişilik özellikleri
# işlevleri vardır : düşünür , konuşur , yürür vb.

"""
class insan :
  def __init__ :
"""
# Out:
# '\nclass insan : \n  def __init__ : \n'

# %%
print(metin.lower()) # hepsini küçük harf yapar
print(metin.title()) # sözcüklerin ilk harfini büyük yapar
print(metin.capitalize()) #baş harfi buyuk yapar
# Out:
# python programlama dili
# Python Programlama Dili
# Python programlama dili

# %%
metin.find("Python") # 0 degeri bulundugu konum yani index degeri
# Out:
# 0

# %%
metin.find("Bora") # -1 , yani bulunamadiğini gosterir.
# Out:
# -1

# %%
metin="Murat ve Murat ve"
metin.count("ve") # verilen karakter dizisinin kaç kere tekrarlandığını söyler
# Out:
# 2

# %%
ad=input("Adiniz: ")
ad=ad.rstrip() #sağındaki boşlukları kaldır
ad=ad.lstrip() # solundaki boşlukları kaldır
print(type(ad))
print(ad)
soyad=input("Soyadiniz: ")
yas=int(input("Yasiniz: "))
# Out:
# Adiniz: Bora
# <class 'str'>
# Bora
# Soyadiniz: Kol
# Yasiniz: 24

# %%
yeni_metin="Ben Java seviyorum"
yeni_metin.replace("Java","Python") # replace metounda neyi neyle değiştireceğimi yazarız.
# Out:
# 'Ben Python seviyorum'

# %%
isimler="Bora,Tuğrul,İrem,Mehmet"
liste = isimler.split(",")
print(liste)
# Out:
# ['Bora', 'Tuğrul', 'İrem', 'Mehmet']

# %%
yeni_metin
# Out:
# 'Ben Java seviyorum'

# %%
yeni_metin.startswith("Ben") # verilen karakter dizisiyle başlıyor mu?
# Out:
# True

# %%
yeni_metin.endswith("rum.") # verilen karakter dizisiyle bitiyor mu?
# Out:
# False

# %%
yeni_metin.endswith("rum") # verilen karakter dizisiyle bitiyor mu?
# Out:
# True

# %%
metin_2="123456"
metin_2.isdigit()
# Out:
# True

# %%
metin_3 = "Abcdve6"
metin_4 = "Abcde"
print(metin_3.isalpha()) # karakter dizisi hep harflerden mi oluşuyor kontrolu
print(metin_4.isalpha())
# Out:
# False
# True

# %%
metin_5 = "123456789"
print(metin_5.isdigit()) # karakter dizisi hep rakamlardan mi oluşuyor kontrolu
# Out:
# True

# %%
"abcd 123".isalnum()## boşluk varsa false döner
# Out:
# False

# %%
"abcd123".isalnum()
# Out:
# True

# %%
meyve_sepeti=["elma","armut","ananas"]
meyve_sepeti.append("muz") # listeye yeni bir eleman ekler
print(meyve_sepeti)
# Out:
# ['elma', 'armut', 'ananas', 'muz']

# %%
meyve_sepeti.insert(2,"Kayısı") # 2 nolu indexe kayısı elemanını ekleyelim
print(meyve_sepeti[2])
# Out:
# Kayısı

# %%
meyve_sepeti_2=["Nar","Kivi", "Avokado"]

# %%
# sepetleri birbirine ekle
meyve_sepeti.extend(meyve_sepeti_2)
meyve_sepeti
# Out:
# ['elma', 'armut', 'Kayısı', 'ananas', 'muz', 'Nar', 'Kivi', 'Avokado']

# %%
meyve_sepeti.remove("Kayısı")
meyve_sepeti
# Out:
# ['elma', 'armut', 'ananas', 'muz', 'Nar', 'Kivi', 'Avokado']

# %%
meyve_sepeti.pop(3) # 3 nolu indexi siler
meyve_sepeti
# Out:
# ['elma', 'armut', 'ananas', 'Nar', 'Kivi', 'Avokado']

# %%
meyve_sepeti.clear() # sepetin icini tamamen temizler
meyve_sepeti
# Out:
# []

# %%
sayilar=[1,3,9,2,4,73,8]
sayilar.sort() # kucukten buyuge siralar
sayilar
# Out:
# [1, 2, 3, 4, 8, 9, 73]

# %%
sayilar.sort(reverse=True) # buyukten kucuge siralar
sayilar
# Out:
# [73, 9, 8, 4, 3, 2, 1]

# %%
harfler=["a","b", "c"]
harfler.reverse()
harfler
# Out:
# ['c', 'b', 'a']

# %%
harfler.index("a")
# Out:
# 2

# %%
takimlar=['GS','FB','BJK','GS','GS']

# %%
takimlar.count('GS')
# Out:
# 3

# %%
# dilimleme
meyve_sepeti = ["elma","armut","kayısı","muz"]
meyve_sepeti[:3] # listenin ilk 3 elemani
# Out:
# ['elma', 'armut', 'kayısı']

# %%
meyve_sepeti[-1] # listenin son elemani
# Out:
# 'muz'

# %%
meyve_sepeti[0] # listenin ilk elemani
# Out:
# 'elma'

# %%
for meyve in meyve_sepeti:
  print(meyve)
# Out:
# elma
# armut
# kayısı
# muz

# %%
toplam = 0

for sayi in range(1,100): # 1 den 100 e kadar sayılarin toplamini bul
  toplam +=sayi

print(toplam)
# Out:
# 4950

# %%
meyve_sepeti[:] #başlangıç ve bitiş yoksa tüm listeyi yazdırır
# Out:
# ['elma', 'armut', 'kayısı', 'muz']

# %%
meyve_sepeti[::-1] # başlangıçtan bitişe tersten başlayarak sıralar
# Out:
# ['muz', 'kayısı', 'armut', 'elma']

# %%
print(*range(1,100,3))
# Out:
# 1 4 7 10 13 16 19 22 25 28 31 34 37 40 43 46 49 52 55 58 61 64 67 70 73 76 79 82 85 88 91 94 97

# %%
araba={"marka":"Toyota",
          "yil": 2015} # key - value çiftleri

araba.get("marka")
# Out:
# 'Toyota'

# %%
ogrenciler={101: {"ad" : "Ali",
                  "soyad" : "Kurt",
                  "bolum_kodu" : 204 ,
                  "notlar" : [70,80,90]
                  },
            102: {"ad" : "Veli",
                  "soyad" : "Demir" ,
                  "bolum_kodu" : 205 ,
                  "notlar" : [60,70,40]
                  }
            }

# %%
ogrenciler.get(101)
# Out:
# {'ad': 'Ali', 'soyad': 'Kurt', 'bolum_kodu': 204, 'notlar': [70, 80, 90]}

# %%
ogrenci_101 = ogrenciler.get(101)

# %%
type(ogrenci_101)
# Out:
# dict

# %%
ogrenci_101.get('notlar')
# Out:
# [70, 80, 90]

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2
