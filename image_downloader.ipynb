# %% [markdown]
# **Görsel İndirme Scripti**

# %%
pip install bing-image-downloader

# %%
from bing_image_downloader import downloader

# %%
query='sparrow bird'

# %%
downloader.download(
   query,
   limit=100,
   output_dir='dataset',
   adult_filter_off=False,
   timeout=60,
   filter='photo',
   verbose=True
)
# Out:
# [%] Downloading Images to /content/dataset/sparrow bird
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 47 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://cdn.pixabay.com/photo/2022/09/10/00/17/bird-7444035_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://cdn.pixabay.com/photo/2021/08/09/15/23/sparrow-6533642_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://cdn.pixabay.com/photo/2024/05/24/18/07/bird-8785552_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://images.pexels.com/photos/929386/pexels-photo-929386.jpeg?cs=srgb&amp;dl=pexels-chrisleboutillier-929386.jpg&amp;fm=jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://cdn.pixabay.com/photo/2023/02/27/08/27/bird-7817776_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://allbirdspecies.com/wp-content/uploads/2025/04/sparrow-bird_11zon-1536x1194.jpg
# [%] File Downloaded !
#
# ...
